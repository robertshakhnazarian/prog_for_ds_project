# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("imdb_movies_dataset_project.csv")

# %%
df
# Out:
#                                          names    date_x  score  \
# 0                                    Creed III    3/2/23     73
# 1                     Avatar: The Way of Water  12/15/22     78
# 2                  The Super Mario Bros. Movie    4/5/23     76
# 3                                      Mummies    1/5/23     70
# 4                                    Supercell   3/17/23     61
# ...                                        ...       ...    ...
# 10173                       20th Century Women  12/28/16     73
# 10174  Delta Force 2: The Colombian Connection   8/24/90     54
# 10175                         The Russia House  12/21/90     61
# 10176         Darkman II: The Return of Durant   7/11/95     55
# 10177       The Swan Princess: A Royal Wedding   7/20/20     70
#
#                                                    genre  \
# 0                                         Drama, Action
# 1                   Science Fiction, Adventure, Action
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10178 entries, 0 to 10177
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         10178 non-null  object
#  1   release_date  10178 non-null  object
#  2   score         10178 non-null  int64
#  3   genre         10093 non-null  object
#  4   overview      10178 non-null  object
#  5   crew          10122 non-null  object
#  6   orig_title    10178 non-null  object
#  7   status        10178 non-null  object
#  8   orig_lang     10178 non-null  object
#  9   budget        10178 non-null  float64
#  10  revenue       10178 non-null  float64
#  11  country       10178 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 954.3+ KB

# %% [markdown]
# # FIRST PART: DATA CLEANING

# %% [markdown]
# #### dropping all duplicates

# %%
df.drop_duplicates()
# Out:
#                                          names    date_x  score  \
# 0                                    Creed III    3/2/23     73
# 1                     Avatar: The Way of Water  12/15/22     78
# 2                  The Super Mario Bros. Movie    4/5/23     76
# 3                                      Mummies    1/5/23     70
# 4                                    Supercell   3/17/23     61
# ...                                        ...       ...    ...
# 10173                       20th Century Women  12/28/16     73
# 10174  Delta Force 2: The Colombian Connection   8/24/90     54
# 10175                         The Russia House  12/21/90     61
# 10176         Darkman II: The Return of Durant   7/11/95     55
# 10177       The Swan Princess: A Royal Wedding   7/20/20     70
#
#                                                    genre  \
# 0                                         Drama, Action
# 1                   Science Fiction, Adventure, Action
# ...

# %% [markdown]
# #### We have no duplicates

# %%
renaming_columns = {'names': 'title', 'date_x': 'release_date', 'overview': 'description', 'budget_x': 'budget'}
df.rename(columns = renaming_columns, inplace = True)

# %%
df["genre"] = df["genre"].str.replace(" ", " ")
print(df["genre"])
df
# Out:
# 0                                            Drama, Action
# 1                       Science Fiction, Adventure, Action
# 2            Animation, Adventure, Family, Fantasy, Comedy
# 3            Animation, Comedy, Family, Adventure, Fantasy
# 4                                                   Action
#                                ...
# 10173                                                Drama
# 10174                                               Action
# 10175                             Drama, Thriller, Romance
# 10176    Action, Adventure, Science Fiction, Thriller, ...
# 10177                           Animation, Family, Fantasy
# Name: genre, Length: 10178, dtype: object
#                                          title release_date  score  \
# 0                                    Creed III       3/2/23     73
# 1                     Avatar: The Way of Water     12/15/22     78
# 2                  The Super Mario Bros. Movie       4/5/23     76
# ...

# %%
df["crew"][0]
# Out:
# "Michael B. Jordan, Adonis Creed, Tessa Thompson, Bianca Taylor, Jonathan Majors, Damien Anderson, Wood Harris, Tony 'Little Duke' Evers, Phylicia Rashād, Mary Anne Creed, Mila Davis-Kent, Amara Creed, Florian Munteanu, Viktor Drago, José Benavidez Jr., Felix Chavez, Selenis Leyva, Laura Chavez"

# %%
#data.shape

# %%
#data.index

# %%
#data.columns

# %%
#data.dtypes

# %%
#data["status"].unique()

# %%
#data["status"].nunique()

# %%
#data.count()

# %%
#data["status"].value_counts()

# %%
#data.info()

# %%
#data[data['status'] == ' In Production']

# %%
#data[data["status"] == " Released"]

# %%
#data.isnull().sum()

# %%
#data.notnull().sum()

# %%
#data.rename(columns = {'status' : 'Status'})

# %%
#print(data["budget_x"].mean())
#print(data["budget_x"].std())
#print(data["revenue"].std())'''

# %%
#data.groupby("revenue")["budget_x"].mean()

# %%
#data["Status"] = data["Status"].str.lstrip()
#data["genre"] = data["genre"].str.replace(' ', ' ')

# %%
#data.drop_duplicates()
